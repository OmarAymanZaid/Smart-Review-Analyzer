# %%
# --------------------
# Import Libraries
# --------------------
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
data = pd.read_csv('../data/raw/Amazon_Reviews.csv', engine='python')

# %%
# --------------------
# Dataset Information
# --------------------
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21214 entries, 0 to 21213
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Reviewer Name       21214 non-null  str
#  1   Profile Link        21163 non-null  str
#  2   Country             21054 non-null  str
#  3   Review Count        21055 non-null  str
#  4   Review Date         21055 non-null  str
#  5   Rating              21055 non-null  str
#  6   Review Title        21055 non-null  str
#  7   Review Text         21055 non-null  str
#  8   Date of Experience  20947 non-null  str
# dtypes: str(9)
# memory usage: 13.7 MB

# %%
# --------------
# Dataset Head
# --------------
data.head()
# Out:
#       Reviewer Name                     Profile Link Country Review Count  \
# 0        Eugene ath  /users/66e8185ff1598352d6b3701a      US     1 review
# 1  Daniel ohalloran  /users/5d75e460200c1f6a6373648c      GB    9 reviews
# 2          p fisher  /users/546cfcf1000064000197b88f      GB   90 reviews
# 3         Greg Dunn  /users/62c35cdbacc0ea0012ccaffa      AU    5 reviews
# 4     Sheila Hannah  /users/5ddbe429478d88251550610e      GB    8 reviews
#
#                 Review Date                  Rating  \
# 0  2024-09-16T13:44:26.000Z  Rated 1 out of 5 stars
# 1  2024-09-16T18:26:46.000Z  Rated 1 out of 5 stars
# 2  2024-09-16T21:47:39.000Z  Rated 1 out of 5 stars
# 3  2024-09-17T07:15:49.000Z  Rated 1 out of 5 stars
# 4  2024-09-16T18:37:17.000Z  Rated 1 out of 5 stars
#
#                                       Review Title  \
# 0       A Store That Doesn't Want to Sell Anything
# 1           Had multiple orders one turned up and…
# ...

# %%
# --------------
# Dataset Tail
# --------------
data.tail()
# Out:
#              Reviewer Name                     Profile Link Country  \
# 21209             Anders T  /users/47bd4ffe0000640001001044      DK
# 21210              David E  /users/495bbbc0000064000100a972      US
# 21211       Joseph Harding  /users/48cfacbf0000640001005d04      GB
# 21212           Mads Dørup  /users/474aaec70000640001000a44      DK
# 21213  Kim Fuglsang Kramer  /users/46d1ed150000640001000051      DK
#
#       Review Count               Review Date                  Rating  \
# 21209     1 review  2009-03-22T13:14:12.000Z  Rated 5 out of 5 stars
# 21210    2 reviews  2008-12-31T18:57:31.000Z  Rated 5 out of 5 stars
# 21211    3 reviews  2008-09-16T13:05:05.000Z  Rated 3 out of 5 stars
# 21212   82 reviews  2008-04-28T11:09:05.000Z  Rated 5 out of 5 stars
# 21213    2 reviews  2007-08-27T17:25:01.000Z  Rated 4 out of 5 stars
#
#                                     Review Title  \
# 21209                                     Fast!!
# ...

# %%
# ---------------
# Dataset Sample
# ---------------
data.sample(5)
# Out:
#             Reviewer Name                     Profile Link Country  \
# 14093             Corinne  /users/5e80e76a8a0cd7e9e770d88e      US
# 12461  Anthi Aristotelous  /users/5fb448d75ad66f001a19ce9e      CY
# 4194          Pablo Jesus  /users/64e9142924b3c30012b67683      GB
# 16051     Augustine White  /users/5d5080fabfd65b2930031d3e      US
# 7009      Parag Sawalakhe  /users/639ef40843d99800122aeec6      IN
#
#       Review Count               Review Date                  Rating  \
# 14093    2 reviews  2020-03-29T23:11:23.000Z  Rated 1 out of 5 stars
# 12461    3 reviews  2020-11-17T22:04:12.000Z  Rated 1 out of 5 stars
# 4194     3 reviews  2023-08-25T22:51:10.000Z  Rated 1 out of 5 stars
# 16051     1 review  2019-08-11T20:56:36.000Z  Rated 1 out of 5 stars
# 7009      1 review  2022-12-18T13:05:54.000Z  Rated 1 out of 5 stars
#
#                                   Review Title  \
# 14093                Horrible Customer Service
# 12461  I was charged extra for order from 133…
# ...

# %%
data['Review Text'][0]
# Out:
# "I registered on the website, tried to order a laptop, entered all the details, but instead of charging me and sending the product, they froze my account, demanding various verification documents. I sent them over. They said they would review them within 24 hours. In reality, it's been a week, and no one can help or give any (truthful) estimate of when it will be resolved; they just tell me to 'wait.' I've never seen such a horrible marketplace in my life. I hope those who came up with this can't buy food in a store, receiving a 'document review request' that takes forever to process."

# %%
data.describe()
# Out:
#        Reviewer Name      Profile Link Country Review Count  \
# count          21214             21163   21054        21055
# unique         18531             21156     148          177
# top         customer  January 21, 2012      US     1 review
# freq              72                 3    9286         5761
#
#                      Review Date                  Rating Review Title  \
# count                      21055                   21055        21055
# unique                     21054                       5        19277
# top     2022-10-05T12:13:39.000Z  Rated 1 out of 5 stars    Excellent
# freq                           2                   13123           52
#
#                   Review Text Date of Experience
# count                   21055              20947
# unique                  20407               3640
# top     Review text not found   January 11, 2021
# freq                      630                 32

# %%
# -------------
# Column Names
# -------------
data.columns
# Out:
# Index(['Reviewer Name', 'Profile Link', 'Country', 'Review Count',
#        'Review Date', 'Rating', 'Review Title', 'Review Text',
#        'Date of Experience'],
#       dtype='str')

# %%
# -------------
# Column Types
# -------------
data.dtypes
# Out:
# Reviewer Name         str
# Profile Link          str
# Country               str
# Review Count          str
# Review Date           str
# Rating                str
# Review Title          str
# Review Text           str
# Date of Experience    str
# dtype: object

# %%
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
# -----------------------------
# Check for Missing Values
# -----------------------------
data.isna().sum()
# Out:
# Reviewer Name           0
# Profile Link           51
# Country               160
# Review Count          159
# Review Date           159
# Rating                159
# Review Title          159
# Review Text           159
# Date of Experience    267
# dtype: int64

# %%
# --------------------------------------------
# Check Missing Values Percentage in Columns
# --------------------------------------------
data.isna().mean().sort_values(ascending=False)
# Out:
# Date of Experience    0.012586
# Country               0.007542
# Review Title          0.007495
# Review Date           0.007495
# Review Count          0.007495
# Review Text           0.007495
# Rating                0.007495
# Profile Link          0.002404
# Reviewer Name         0.000000
# dtype: float64

# %%
data = data.drop(columns=[
    'Reviewer Name',
    'Profile Link',
    'Review Count',
    'Review Date',
    'Date of Experience'
])

# %%
data = data.dropna(subset=['Review Text', 'Rating'])
data['Review Title'] = data['Review Title'].fillna('')
data['Country'] = data['Country'].fillna('Unknown')

# %%
data['Rating'] = data['Rating'].str.extract(r'(\d)').astype(float)
data = data.dropna(subset=['Rating'])
data['Rating'] = data['Rating'].astype(int)

# %%
data['Sentiment'] = data['Rating'].apply(lambda x: 1 if x >= 4 else 0 if x <= 2 else None)
data = data.dropna(subset=['Sentiment'])
data['Sentiment'] = data['Sentiment'].astype(int)

# %%
data['Full Review'] = data['Review Title'] + " " + data['Review Text']

# %%
data.to_csv("../data/processed/clean_reviews.csv", index=False)
